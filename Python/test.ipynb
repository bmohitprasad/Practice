# %%
n = int(input("Enter number of rows:"))
for i in range(1,n+1):
    print(" " * (n-i),end="")
    print("* "*i)
    # print(i)
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n = int(input())

for i in range(1, n+1):
    print(" " * (n-i), end = "")
    print("* " * i)
# Out:
#     *
#    * *
#   * * *
#  * * * *
# * * * * *

# %%
n = int(input())

for i in range(1, n+1):
    print(" " * (i - 1), end = "")
    print("*"* (n - i + 1))
# Out:
# *****
#  ****
#   ***
#    **
#     *

# %%
n = int(input())

for i in range(1, n+1):
    print("* " * i)
    print(" " * (n-i), end = "")
# Out:
# *
#     * *
#    * * *
#   * * * *
#  * * * * *
