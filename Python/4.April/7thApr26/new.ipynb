# %%
try:
    name = 'Mohit'
    print(pin)

except Exception as e:
    print(e)
# Out:
# name 'pin' is not defined

# %%
try:
    name = 'Mohit'
    print(name)
    10 / 0

except NameError:
    print('-----Name erro-----')

except ZeroDivisionError:
    print('-----Zero division error-----')
# Out:
# Mohit
# -----Zero division error-----

# %%
class employee:
    def __init__(self):
        self.pin = 101

try:
    obj = employee()
    print(obj.pin)

except Exception as e:
    print(e)
# Out:
# 101

# %%
class employee:
    def __init__(self):
        self.pin = 101

obj = employee()

try:
    print(obj.name)

except AttributeError:
    print('____Attribute error____')
# Out:
# ____Attribute error____

# %%
try:
    v = 10 + "c"
    print(v)
    

except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    # v = 10 + "c"
    # print(v)
    print(int('python'))

except TypeError:
    print('Type error')

except ValueError:
    print('Value error')
# Out:
# Value error

# %%
try:
    print('outer try')

    try: 
        print('inner try')

    except: 
        print('inner except')

except FileNotFoundError: 
    print("oter except")
except:
    print('default error')
# Out:
# outer try
# inner try
