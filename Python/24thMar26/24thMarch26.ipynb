# %%
import qrcode
qr = qrcode.make("https://github.com/bmohitprasad")

qr.save('img.png')
qr.show()
# Out:
# /usr/bin/eog: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE

# %%
import qrcode
qr = qrcode.QRCode(box_size = 10)
qr.add_data ('This is my first qr')
qr.make()

img = qr.make_image(fill_color = 'blue')

img.save('img2.png')
img.show()
# Out:
# /usr/bin/eog: symbol lookup error: /snap/core20/current/lib/x86_64-linux-gnu/libpthread.so.0: undefined symbol: __libc_pthread_init, version GLIBC_PRIVATE
