# %% [markdown]
# ##### Module - A file containing a bunch of functions

# %% [markdown]
# ###### Check for a perfect square

# %%
import math

number = int(input("Enter a number: "))
root = math.sqrt(number)

if root*root == number:
    print("Perfect square")

else:
    print("Not a Perfect square")
# Out:
# Not a Perfect square

# %%
def is_perfect_square(num):
    return math.sqrt(num)*math.sqrt(num) == num

# %% [markdown]
# ##### Approach 2
# 50
#
# 1*1
# 2*2
# 3*3
# ...
#
# 7*7 <= 50
# 8*8 <= 50 : False

# %%
def is_perfect_square (num):
    i = 1

    while (i * i <= num):
        if i * i == num:
            return True
        i += 1

    return False

num = int(input("Enter the number: "))

print ("Perfect square" if is_perfect_square(num) else "Not a perfect square")
# Out:
# Perfect square

# %% [markdown]
# ##### 25 = 1 + 3 + 5 + 7 + 9
# ##### 16 = 1 + 3 + 5 + 7

# %%
def is_perfect_square (number):
    odd = 1
    while number > 0:
        number = number - odd
        odd = odd + 2

    return number

number = int(input("Enter a number: "))
print("Perfect Square" if is_perfect_square(49) == 0 else "Not a perfect square")
# Out:
# Perfect Square

# %%
year = 1904

if (year % 2 == 0):
    if (year % 100 == 0):
        if (year % 400 == 0):
            print("Leap Year")
        else:
            print("Not a Leap Year")
    else:
        print("Leap Year")
else: 
    print("Not a Leap Year")
# Out:
# Leap Year
